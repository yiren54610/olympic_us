# %%
import pandas as pd

# %%
df = pd.read_csv('medals - wide.csv')

# %%
df.head()
# Out:
#    year  sum  Archery  Artistic Swimming  Athletics  Baseball  Basketball  \
# 0  1984  174      2.0                NaN       40.0       NaN           2
# 1  1988   94      3.0                NaN       26.0       NaN           2
# 2  1992  108      NaN                NaN       30.0       NaN           2
# 3  1996  101      2.0                NaN       23.0       1.0           2
# 4  2000   93      2.0                NaN       16.0       1.0           2
#
#    Basketball 3x3  BMX Freestyle  Boxing  ...  Swimming  \
# 0             NaN            NaN      11  ...        34
# 1             NaN            NaN       8  ...        18
# 2             NaN            NaN       3  ...        27
# 3             NaN            NaN       6  ...        26
# 4             NaN            NaN       4  ...        33
#
#    Synchronized swimming  Taekwondo  Tennis  Track and Field  Triathlon  \
# 0                    2.0        NaN     NaN              NaN        NaN
# ...
